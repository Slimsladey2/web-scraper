# %% [markdown]
# # Clustering Practice - Data Scraping
#
# This notebook will be used to source each of the datasets. I will attempt to use HTML scraping in order to extract the datasets from each postcode within South Oxfordshire.

# %% [markdown]
# URL for Cholsey containing OX10 9QW
# http://www.ukcensusdata.com/cholsey-and-wallingford-south-e00145773/household-size-qs406ew

# %% [markdown]
# ## Import Libraries

# %%
# Pandas for data manipulations
import pandas as pd

# requests and Beautiful soup for html parsing
from bs4 import BeautifulSoup
import requests

# %%
url = r'http://www.ukcensusdata.com/south-oxfordshire-e07000179'
website_url = requests.get(url).text
soup = BeautifulSoup(website_url,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <head>
#   <title>
#    South Oxfordshire - UK Census Data 2011
#   </title>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content=" South Oxfordshire. 2011 Census Data for all census areas in England and Wales." name="description"/>
#   <meta content="Good Stuff IT Services" name="author"/>
#   <meta content="area" name="foo"/>
#   <meta content="832605246" property="fb:admins"/>
#   <meta content="B574B9C7F090DC5771DB3C1A2943B5B1" name="msvalidate.01"/>
#   <meta content="YPO8ceTkDl37RPOcHU6tut7QCIEk4r9G_95t63coe_o" name="google-site-verification"/>
#   <meta content="UK Census Data" property="og:site_name"/>
#   <link href="/framework/main.css" rel="stylesheet" type="text/css"/>
#   <link href="https://plus.google.com/106650210520079476747" rel="publisher"/>
#   <link href="https://plus.google.com/106650210520079476747" rel="author"/>
#   <meta content="3f9560f45b8f97bc32e8ca7aef33905d" name="fpn-validate"/>
#   <link href="http://www.ukcensusdata.com/south-oxfordshire-e07000179" rel="canonical"/>
#   <script type="text/javascript">
#    var switchTo5x=true;
#   </script>
#   <script src="https://ws.sharethis.com/button/buttons.js" type="text/javascript">
#   </script>
#   <script src="https://sd.sharethis.com/loader.js" type="text/javascript">
#   </script>
#   <script src="/js/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="/js/fancybox/source/jquery.fancybox.js?v=2.1.4" type="text/javascript">
#   </script>
#   <link href="/js/fancybox/source/jquery.fancybox.css?v=2.1.4" media="screen" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 	$(".floater").fancybox({
# 		fitToView	: false,
# 		width		: '95%',
# 		height		: '95%',
# 		autoSize	: false,
# 		closeClick	: false,
# 		openEffect	: 'elastic',
# 		closeEffect	: 'elastic'
# 	});
# });
#   </script>
#   <script language="JavaScript">
#    function unFrame() {
#     if (self != top)
#       top.location.href = self.location.href;
# }
#
# function showBox(text, obj, e) {
# 	obj.onmouseout = hideBox;
# 	obj.onmousemove = moveBox;
# 	node = document.createElement('div');
# 	node.style.left = e.layerX + 'px';
# 	node.style.top = e.layerY + 'px';
# 	node.id = 'popBox';
# 	node.innerHTML = text;
# 	obj.appendChild(node);
# }
# function moveBox(e) {
# 	node = document.getElementById('popBox');
# 	node.style.left = e.layerX + 'px';
# 	node.style.top = e.layerY + 'px';
# }
# function hideBox() {
# 	node = document.getElementById('popBox');
# 	node.parentNode.removeChild(node);
# }
#   </script>
#   <script>
#    function dataswitch(a,b){
#    $("#infoblock").load('/handlers/datawotsit.php?'+a+'='+b).hide().fadeIn('slow');
#    $('a.active').removeClass('active');
#    $(this).addClass('active');
# }
# function dataselect(){
# 	var x=document.getElementById("switcher");
# 	var y=x.options[x.selectedIndex].value;
# 	$("#infoblock").load('/handlers/datawotsit.php?'+y).hide().fadeIn('slow');
# 	$('a.active').removeClass('active');
# 	$(this).addClass('active');
# }
#   </script>
#  </head>
#  <body onload="unFrame()">
#   <div id="header">
#    <div id="header-inner">
#     <div style="float:right">
#      <form action="/postcode/" method="get">
#       <input name="pc" onfocus="if(this.value == 'postcode') { this.value = ''; }" size="8" type="text" value="postcode"/>
#       <input type="submit" value="Go"/>
#      </form>
#     </div>
#     <h1 class="header">
#      UK Census Data
#     </h1>
#    </div>
#   </div>
#   <div id="container">
#    <div id="container-inner">
#     <div id="content">
#      <a href="/">
#       Home
#      </a>
#      »
#      <a href="/england-and-wales-k04000001">
#       England and Wales
#      </a>
#      »
#      <a href="/england-e92000001">
#       England
#      </a>
#      »
#      <a href="/south-east-e12000008">
#       South East
#      </a>
#      »
#      <a href="/oxfordshire-e10000025">
#       Oxfordshire
#      </a>
#      » South Oxfordshire
#      <h1>
#       South Oxfordshire
#      </h1>
#      <script src="https://maps.googleapis.com/maps/api/js?sensor=false">
#      </script>
#      <script>
#       /* <![CDATA[ */
#     var map;
#     window.onload = function() {
#         var mapOptions = {
#           zoom: 11,
#           mapTypeId: google.maps.MapTypeId.ROADMAP
#         }
#         var map = new google.maps.Map(document.getElementById('map-canvas'), mapOptions);
#         var areaLayer = new google.maps.KmlLayer('http://kml.ukcensusdata.com/kmlfiles/E07000179.kml');
#         areaLayer.setMap(map);
# 	      }
#      </script>
#      <div style="float:right">
#       <script type="text/javascript">
#        <!--
# google_ad_client = "pub-8138990502704272";
# google_ad_width = 728;
# google_ad_height = 90;
# google_ad_format = "728x90_as";
# google_ad_type = "text";
# google_ad_channel ="";
# google_color_border = "FFFFFF";
# google_color_bg = "FFFFFF";
# google_color_link = "0066CC";
# google_color_url = "0066CC";
# google_color_text = "000000";
# //-->
#       </script>
#       <script src="https://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#       </script>
#      </div>
#      <div id="map-canvas" style="width:728px; height:500px; float:right; clear:right">
#      </div>
#      <div style="padding:10px 10px 0 0; width:250px;">
#       <h3>
#        Drill down further:
#       </h3>
#       <h4>
#        Wards within South Oxfordshire
#       </h4>
#       <p>
#        <a href="/aston-rowant-e05006569">
#         Aston Rowant
#        </a>
#        <br/>
#        <a href="/benson-e05006570">
#         Benson
#        </a>
#        <br/>
#        <a href="/berinsfield-e05006571">
#         Berinsfield
#        </a>
#        <br/>
#        <a href="/brightwell-e05006572">
#         Brightwell
#        </a>
#        <br/>
#        <a href="/chalgrove-e05006573">
#         Chalgrove
#        </a>
#        <br/>
#        <a href="/chiltern-woods-e05006574">
#         Chiltern Woods
#        </a>
#        <br/>
#        <a href="/chinnor-e05006575">
#         Chinnor
#        </a>
#        <br/>
#        <a href="/cholsey-and-wallingford-south-e05006576">
#         Cholsey and Wallingford South
#        </a>
#        <br/>
#        <a href="/crowmarsh-e05006577">
#         Crowmarsh
#        </a>
#        <br/>
#        <a href="/didcot-all-saints-e05006578">
#         Didcot All Saints
#        </a>
#        <br/>
#        <a href="/didcot-ladygrove-e05006579">
#         Didcot Ladygrove
#        </a>
#        <br/>
#        <a href="/didcot-northbourne-e05006580">
#         Didcot Northbourne
#        </a>
#        <br/>
#        <a href="/didcot-park-e05006581">
#         Didcot Park
#        </a>
#        <br/>
#        <a href="/forest-hill-and-holton-e05006582">
#         Forest Hill and Holton
#        </a>
#        <br/>
#        <a href="/garsington-e05006583">
#         Garsington
#        </a>
#        <br/>
#        <a href="/goring-e05006584">
#         Goring
#        </a>
#        <br/>
#        <a href="/great-milton-e05006585">
#         Great Milton
#        </a>
#        <br/>
#        <a href="/hagbourne-e05006586">
#         Hagbourne
#        </a>
#        <br/>
#        <a href="/henley-north-e05006587">
#         Henley North
#        </a>
#        <br/>
#        <a href="/henley-south-e05006588">
#         Henley South
#        </a>
#        <br/>
#        <a href="/sandford-e05006589">
#         Sandford
#        </a>
#        <br/>
#        <a href="/shiplake-e05006590">
#         Shiplake
#        </a>
#        <br/>
#        <a href="/sonning-common-e05006591">
#         Sonning Common
#        </a>
#        <br/>
#        <a href="/thame-north-e05006592">
#         Thame North
#        </a>
#        <br/>
#        <a href="/thame-south-e05006593">
#         Thame South
#        </a>
#        <br/>
#        <a href="/wallingford-north-e05006594">
#         Wallingford North
#        </a>
#        <br/>
#        <a href="/watlington-e05006595">
#         Watlington
#        </a>
#        <br/>
#        <a href="/wheatley-e05006596">
#         Wheatley
#        </a>
#        <br/>
#        <a href="/woodcote-e05006597">
#         Woodcote
#        </a>
#        <br/>
#       </p>
#      </div>
#      <div style="clear:both; padding-top:10px">
#       <div style="padding:20px 0 0 0; float:right; width:600px;">
#       </div>
#      </div>
#      <h2>
#       Detailed Stats
#      </h2>
#      <div style="clear:both">
#       <form action="/" id="dataselect" method="get">
#        <select id="switcher" name="switcher" onchange="dataselect()">
#         <option value="">
#          --select--
#         </option>
#         <option value="E07000179=QS402EW">
#          Accomodation Type - Households (Quick Stats) QS402EW
#         </option>
#         <option value="E07000179=QS401EW">
#          Accomodation Type - People (Quick Stats) QS401EW
#         </option>
#         <option value="E07000179=QS110EW">
#          Adult Lifestage (alternative adult definition) (Quick Stats) QS110EW
#         </option>
#         <option value="E07000179=KS106EW">
#          Adults Not in Employment (Key Stats) KS106EW
#         </option>
#         <option value="E07000179=QS103EW">
#          Age by Single Year (Quick Stats) QS103EW
#         </option>
#         <option value="E07000179=QS802EW">
#          Age of Arrival in UK (Quick Stats) QS802EW
#         </option>
#         <option value="E07000179=KS102EW">
#          Age Structure (Key Stats) KS102EW
#         </option>
#         <option value="E07000179=QS416EW">
#          Car or Van Availability (Quick Stats) QS416EW
#         </option>
#         <option value="E07000179=KS404EW">
#          Car or Van Availability (Key Stats) KS404EW
#         </option>
#         <option value="E07000179=QS415EW">
#          Central Heating (Quick Stats) QS415EW
#         </option>
#         <option value="E07000179=QS420EW">
#          Communal establishment management and type (Quick Stats) QS420EW
#         </option>
#         <option value="E07000179=QS421EW">
#          Communal establishment management and type - People (Quick Stats) QS421EW
#         </option>
#         <option value="E07000179=KS405EW">
#          Communal Establishments and Residents (Key Stats) KS405EW
#         </option>
#         <option value="E07000179=KS204EW">
#          Country of Birth (Key Stats) KS204EW
#         </option>
#         <option value="E07000179=QS203EW">
#          Country of Birth (detailed) (Quick Stats) QS203EW
#         </option>
#         <option value="E07000179=QS418EW">
#          Dwellings (Quick Stats) QS418EW
#         </option>
#         <option value="E07000179=KS401EW">
#          Dwellings, Household Spaces and Accomodation Type (Key Stats) KS401EW
#         </option>
#         <option value="E07000179=QS601EW">
#          Economic Activity (Quick Stats) QS601EW
#         </option>
#         <option value="E07000179=KS601EW">
#          Economic Activity (Key Stats) KS601EW
#         </option>
#         <option value="E07000179=KS603EW">
#          Economic Activity - Females (Key Stats) KS603EW
#         </option>
#         <option value="E07000179=QS603EW">
#          Economic Activity - Full-time Students (Quick Stats) QS603EW
#         </option>
#         <option value="E07000179=KS602EW">
#          Economic Activity - Males (Key Stats) KS602EW
#         </option>
#         <option value="E07000179=QS602EW">
#          Economic Activity of Household Reference Person (Quick Stats) QS602EW
#         </option>
#         <option value="E07000179=QS201EW">
#          Ethnic Group (Quick Stats) QS201EW
#         </option>
#         <option value="E07000179=KS201EW">
#          Ethnic Group (Key Stats) KS201EW
#         </option>
#         <option value="E07000179=CT0010">
#          Ethnic group (Write-in Responses) CT0010
#         </option>
#         <option value="E07000179=QS211EW">
#          Ethnic Group (detailed) (Quick Stats) QS211EW
#         </option>
#         <option value="E07000179=QS118EW">
#          Families with Dependent Children (Quick Stats) QS118EW
#         </option>
#         <option value="E07000179=QS302EW">
#          General Health (Quick Stats) QS302EW
#         </option>
#         <option value="E07000179=KS301EW">
#          Health and Provision of Unpaid Care (Key Stats) KS301EW
#         </option>
#         <option value="E07000179=QS501EW">
#          Highest Level of Qualification (Quick Stats) QS501EW
#         </option>
#         <option value="E07000179=QS604EW">
#          Hour Worked (Quick Stats) QS604EW
#         </option>
#         <option value="E07000179=KS604EW">
#          Hours Worked (Key Stats) KS604EW
#         </option>
#         <option value="E07000179=QS115EW">
#          Household Comp. (alternative child/adult definition) - Households (Quick Stats) QS115EW
#         </option>
#         <option value="E07000179=QS114EW">
#          Household Comp. (alternative child/adult definition) - People (Quick Stats) QS114EW
#         </option>
#         <option value="E07000179=KS105EW">
#          Household Composition (Key Stats) KS105EW
#         </option>
#         <option value="E07000179=QS113EW">
#          Household Composition - Households (Quick Stats) QS113EW
#         </option>
#         <option value="E07000179=QS112EW">
#          Household Composition - People (Quick Stats) QS112EW
#         </option>
#         <option value="E07000179=KS206EW">
#          Household Language (Key Stats) KS206EW
#         </option>
#         <option value="E07000179=QS111EW">
#          Household Lifestage (Quick Stats) QS111EW
#         </option>
#         <option value="E07000179=QS406EW">
#          Household Size (Quick Stats) QS406EW
#         </option>
#         <option value="E07000179=QS417EW">
#          Household Spaces (Quick Stats) QS417EW
#         </option>
#         <option value="E07000179=QS116EW">
#          Household Type (Quick Stats) QS116EW
#         </option>
#         <option value="E07000179=QS119EW">
#          Households by Deprivation Dimensions (Quick Stats) QS119EW
#         </option>
#         <option value="E07000179=QS605EW">
#          Industry (Quick Stats) QS605EW
#         </option>
#         <option value="E07000179=KS605EW">
#          Industry (Key Stats) KS605EW
#         </option>
#         <option value="E07000179=KS607EW">
#          Industry - Females (Key Stats) KS607EW
#         </option>
#         <option value="E07000179=KS606EW">
#          Industry - Males (Key Stats) KS606EW
#         </option>
#         <option value="E07000179=QS803EW">
#          Length of Residence in UK (Quick Stats) QS803EW
#         </option>
#         <option value="E07000179=QS108EW">
#          Living Arrangements (Quick Stats) QS108EW
#         </option>
#         <option value="E07000179=KS104EW">
#          Living Arrangements (Key Stats) KS104EW
#         </option>
#         <option value="E07000179=KS107EW">
#          Lone Parent Households With Dependent Children (Key Stats) KS107EW
#         </option>
#         <option value="E07000179=QS303EW">
#          Long-term Health Problem or Disability (Quick Stats) QS303EW
#         </option>
#         <option value="E07000179=QS204EW">
#          Main Language (Quick Stats) QS204EW
#         </option>
#         <option value="E07000179=KS103EW">
#          Marital and Civil Partnership Status (Key Stats) KS103EW
#         </option>
#         <option value="E07000179=QS701EW">
#          Method of Travel to Work (Quick Stats) QS701EW
#         </option>
#         <option value="E07000179=QS202EW">
#          Multiple Ethnic Groups (Quick Stats) QS202EW
#         </option>
#         <option value="E07000179=KS202EW">
#          National Identity (Key Stats) KS202EW
#         </option>
#         <option value="E07000179=QS607EW">
#          NS-Sec (Quick Stats) QS607EW
#         </option>
#         <option value="E07000179=KS611EW">
#          NS-SeC (Key Stats) KS611EW
#         </option>
#         <option value="E07000179=KS613EW">
#          NS-SeC - Females (Key Stats) KS613EW
#         </option>
#         <option value="E07000179=KS612EW">
#          NS-SeC - Males (Key Stats) KS612EW
#         </option>
#         <option value="E07000179=QS610EW">
#          NS-Sec of Household Reference Person - HRP Aged under 65 (Quick Stats) QS610EW
#         </option>
#         <option value="E07000179=QS609EW">
#          NS-Sec of Household Reference Person - People Aged under 65 (Quick Stats) QS609EW
#         </option>
#         <option value="E07000179=QS608EW">
#          NS-SeC of Household Reference Person - People Aged under 65 (Quick Stats) QS608EW
#         </option>
#         <option value="E07000179=QS411EW">
#          Number of Bedrooms (Quick Stats) QS411EW
#         </option>
#         <option value="E07000179=QS407EW">
#          Number of Rooms (Quick Stats) QS407EW
#         </option>
#         <option value="E07000179=QS412EW">
#          Occupancy Rating (Bedrooms) (Quick Stats) QS412EW
#         </option>
#         <option value="E07000179=QS408EW">
#          Occupancy Rating (rooms) (Quick Stats) QS408EW
#         </option>
#         <option value="E07000179=KS608EW">
#          Occupation (Key Stats) KS608EW
#         </option>
#         <option value="E07000179=QS606EW">
#          Occupation (Minor Groups) (Quick Stats) QS606EW
#         </option>
#         <option value="E07000179=KS610EW">
#          Occupation - Females (Key Stats) KS610EW
#         </option>
#         <option value="E07000179=KS609EW">
#          Occupation - Males (Key Stats) KS609EW
#         </option>
#         <option value="E07000179=KS205EW">
#          Passport Held (Key Stats) KS205EW
#         </option>
#         <option value="E07000179=QS117EW">
#          People Aged 18 to 64 Living In a One Adult Household (Quick Stats) QS117EW
#         </option>
#         <option value="E07000179=QS413EW">
#          Persons per Bedroom - Households (Quick Stats) QS413EW
#         </option>
#         <option value="E07000179=QS414EW">
#          Persons per Bedroom - People (Quick Stats) QS414EW
#         </option>
#         <option value="E07000179=QS409EW">
#          Persons per Room - Households (Quick Stats) QS409EW
#         </option>
#         <option value="E07000179=QS410EW">
#          Persons per Room - people (Quick Stats) QS410EW
#         </option>
#         <option value="E07000179=QS102EW">
#          Population Density (Quick Stats) QS102EW
#         </option>
#         <option value="E07000179=QS419EW">
#          Position in Communal Establishment (Quick Stats) QS419EW
#         </option>
#         <option value="E07000179=QS205EW">
#          Proficiency in English (Quick Stats) QS205EW
#         </option>
#         <option value="E07000179=QS301EW">
#          Provision of Unpaid Care (Quick Stats) QS301EW
#         </option>
#         <option value="E07000179=KS501EW">
#          Qualifications and Students (Key Stats) KS501EW
#         </option>
#         <option value="E07000179=QS502EW">
#          Qualifications Gained (Quick Stats) QS502EW
#         </option>
#         <option value="E07000179=QS208EW">
#          Religion (Quick Stats) QS208EW
#         </option>
#         <option value="E07000179=KS209EW">
#          Religion (Key Stats) KS209EW
#         </option>
#         <option value="E07000179=QS210EW">
#          Religion (detailed) (Quick Stats) QS210EW
#         </option>
#         <option value="E07000179=QS101EW">
#          Residence Type (Quick Stats) QS101EW
#         </option>
#         <option value="E07000179=KS403EW">
#          Rooms, Bedrooms and Central Heating (Key Stats) KS403EW
#         </option>
#         <option value="E07000179=QS105EW">
#          Schoolchildren and full-time students at their non term-time (Quick Stats) QS105EW
#         </option>
#         <option value="E07000179=QS106EW">
#          Second Address (Quick Stats) QS106EW
#         </option>
#         <option value="E07000179=QS104EW">
#          Sex (Quick Stats) QS104EW
#         </option>
#         <option value="E07000179=KS402EW">
#          Tenure (Key Stats) KS402EW
#         </option>
#         <option value="E07000179=QS404EW">
#          Tenure - Household Reference Person aged 65 and Over (Quick Stats) QS404EW
#         </option>
#         <option value="E07000179=QS405EW">
#          Tenure - Households (Quick Stats) QS405EW
#         </option>
#         <option value="E07000179=QS403EW">
#          Tenure - People (Quick Stats) QS403EW
#         </option>
#         <option value="E07000179=KS101EW">
#          Usual Resident Population (Key Stats) KS101EW
#         </option>
#         <option value="E07000179=KS208WA">
#          Welsh Language Profile (Key Stats) KS208WA
#         </option>
#         <option value="E07000179=QS206WA">
#          Welsh Language Skills (Quick Stats) QS206WA
#         </option>
#         <option value="E07000179=KS207WA">
#          Welsh Language Skills (Key Stats) KS207WA
#         </option>
#         <option value="E07000179=QS207WA">
#          Welsh Language Skills (Detaiiled) (Quick Stats) QS207WA
#         </option>
#         <option value="E07000179=QS612EW">
#          Year Last Worked (Quick Stats) QS612EW
#         </option>
#         <option value="E07000179=QS801EW">
#          Year of Arrival in UK (Quick Stats) QS801EW
#         </option>
#        </select>
#        <noscript>
#         <input name="nonjs" type="submit" value="Go"/>
#        </noscript>
#       </form>
#      </div>
#      <div id="infoblock" style="clear:both;">
#       <p>
#        Select the data you want to see from the dropdown list.
#       </p>
#       <p>
#        Some data tables are available as both "Quick Stats" and "Key Stats". In general, Key Stats
# 	tables have more detail, often including percentage values as well as simple numeric counts.
#       </p>
#      </div>
#      <div style="clear:both;">
#       <div id="disqus_thread">
#       </div>
#       <script type="text/javascript">
#        var disqus_shortname = 'ukcensusdata';
# var disqus_url = 'http://www.ukcensusdata.com/south-oxfordshire-e07000179';
# var disqus_title = '2011 census data for South Oxfordshire';
# (function() {
# var dsq = document.createElement('script'); dsq.type = 'text/javascript'; dsq.async = true;
# dsq.src = '//' + disqus_shortname + '.disqus.com/embed.js';
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(dsq);
# })();
#       </script>
#      </div>
#      <br style="clear:both"/>
#      <div style="float:right">
#       <script type="text/javascript">
#        <!--
# google_ad_client = "pub-8138990502704272";
# google_ad_width = 728;
# google_ad_height = 90;
# google_ad_format = "728x90_as";
# google_ad_type = "text";
# google_ad_channel ="";
# google_color_border = "FFFFFF";
# google_color_bg = "FFFFFF";
# google_color_link = "0066CC";
# google_color_url = "0066CC";
# google_color_text = "000000";
# //-->
#       </script>
#       <script src="https://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#       </script>
#      </div>
#      <p>
#       Contains National Statistics data © Crown copyright and database right 2012
#      </p>
#      <p>
#       Contains Ordnance Survey data ©  Crown copyright and database right 2012
#      </p>
#      <br style="clear:both"/>
#      <form action="/" id="dataselect">
#       <select id="switcher" onchange="dataselect()">
#        <option value="E07000179=QS402EW">
#         Accomodation Type - Households Quick Stats QS402EW
#        </option>
#        <option value="E07000179=QS401EW">
#         Accomodation Type - People Quick Stats QS401EW
#        </option>
#        <option value="E07000179=QS110EW">
#         Adult Lifestage (alternative adult definition) Quick Stats QS110EW
#        </option>
#        <option value="E07000179=KS106EW">
#         Adults Not in Employment Key Stats KS106EW
#        </option>
#        <option value="E07000179=QS103EW">
#         Age by Single Year Quick Stats QS103EW
#        </option>
#        <option value="E07000179=QS802EW">
#         Age of Arrival in UK Quick Stats QS802EW
#        </option>
#        <option value="E07000179=KS102EW">
#         Age Structure Key Stats KS102EW
#        </option>
#        <option value="E07000179=QS416EW">
#         Car or Van Availability Quick Stats QS416EW
#        </option>
#        <option value="E07000179=KS404EW">
#         Car or Van Availability Key Stats KS404EW
#        </option>
#        <option value="E07000179=QS415EW">
#         Central Heating Quick Stats QS415EW
#        </option>
#        <option value="E07000179=QS420EW">
#         Communal establishment management and type Quick Stats QS420EW
#        </option>
#        <option value="E07000179=QS421EW">
#         Communal establishment management and type - People Quick Stats QS421EW
#        </option>
#        <option value="E07000179=KS405EW">
#         Communal Establishments and Residents Key Stats KS405EW
#        </option>
#        <option value="E07000179=KS204EW">
#         Country of Birth Key Stats KS204EW
#        </option>
#        <option value="E07000179=QS203EW">
#         Country of Birth (detailed) Quick Stats QS203EW
#        </option>
#        <option value="E07000179=QS418EW">
#         Dwellings Quick Stats QS418EW
#        </option>
#        <option value="E07000179=KS401EW">
#         Dwellings, Household Spaces and Accomodation Type Key Stats KS401EW
#        </option>
#        <option value="E07000179=QS601EW">
#         Economic Activity Quick Stats QS601EW
#        </option>
#        <option value="E07000179=KS601EW">
#         Economic Activity Key Stats KS601EW
#        </option>
#        <option value="E07000179=KS603EW">
#         Economic Activity - Females Key Stats KS603EW
#        </option>
#        <option value="E07000179=QS603EW">
#         Economic Activity - Full-time Students Quick Stats QS603EW
#        </option>
#        <option value="E07000179=KS602EW">
#         Economic Activity - Males Key Stats KS602EW
#        </option>
#        <option value="E07000179=QS602EW">
#         Economic Activity of Household Reference Person Quick Stats QS602EW
#        </option>
#        <option value="E07000179=QS201EW">
#         Ethnic Group Quick Stats QS201EW
#        </option>
#        <option value="E07000179=KS201EW">
#         Ethnic Group Key Stats KS201EW
#        </option>
#        <option value="E07000179=CT0010">
#         Ethnic group Write-in Responses CT0010
#        </option>
#        <option value="E07000179=QS211EW">
#         Ethnic Group (detailed) Quick Stats QS211EW
#        </option>
#        <option value="E07000179=QS118EW">
#         Families with Dependent Children Quick Stats QS118EW
#        </option>
#        <option value="E07000179=QS302EW">
#         General Health Quick Stats QS302EW
#        </option>
#        <option value="E07000179=KS301EW">
#         Health and Provision of Unpaid Care Key Stats KS301EW
#        </option>
#        <option value="E07000179=QS501EW">
#         Highest Level of Qualification Quick Stats QS501EW
#        </option>
#        <option value="E07000179=QS604EW">
#         Hour Worked Quick Stats QS604EW
#        </option>
#        <option value="E07000179=KS604EW">
#         Hours Worked Key Stats KS604EW
#        </option>
#        <option value="E07000179=QS115EW">
#         Household Comp. (alternative child/adult definition) - Households Quick Stats QS115EW
#        </option>
#        <option value="E07000179=QS114EW">
#         Household Comp. (alternative child/adult definition) - People Quick Stats QS114EW
#        </option>
#        <option value="E07000179=KS105EW">
#         Household Composition Key Stats KS105EW
#        </option>
#        <option value="E07000179=QS113EW">
#         Household Composition - Households Quick Stats QS113EW
#        </option>
#        <option value="E07000179=QS112EW">
#         Household Composition - People Quick Stats QS112EW
#        </option>
#        <option value="E07000179=KS206EW">
#         Household Language Key Stats KS206EW
#        </option>
#        <option value="E07000179=QS111EW">
#         Household Lifestage Quick Stats QS111EW
#        </option>
#        <option value="E07000179=QS406EW">
#         Household Size Quick Stats QS406EW
#        </option>
#        <option value="E07000179=QS417EW">
#         Household Spaces Quick Stats QS417EW
#        </option>
#        <option value="E07000179=QS116EW">
#         Household Type Quick Stats QS116EW
#        </option>
#        <option value="E07000179=QS119EW">
#         Households by Deprivation Dimensions Quick Stats QS119EW
#        </option>
#        <option value="E07000179=QS605EW">
#         Industry Quick Stats QS605EW
#        </option>
#        <option value="E07000179=KS605EW">
#         Industry Key Stats KS605EW
#        </option>
#        <option value="E07000179=KS607EW">
#         Industry - Females Key Stats KS607EW
#        </option>
#        <option value="E07000179=KS606EW">
#         Industry - Males Key Stats KS606EW
#        </option>
#        <option value="E07000179=QS803EW">
#         Length of Residence in UK Quick Stats QS803EW
#        </option>
#        <option value="E07000179=QS108EW">
#         Living Arrangements Quick Stats QS108EW
#        </option>
#        <option value="E07000179=KS104EW">
#         Living Arrangements Key Stats KS104EW
#        </option>
#        <option value="E07000179=KS107EW">
#         Lone Parent Households With Dependent Children Key Stats KS107EW
#        </option>
#        <option value="E07000179=QS303EW">
#         Long-term Health Problem or Disability Quick Stats QS303EW
#        </option>
#        <option value="E07000179=QS204EW">
#         Main Language Quick Stats QS204EW
#        </option>
#        <option value="E07000179=KS103EW">
#         Marital and Civil Partnership Status Key Stats KS103EW
#        </option>
#        <option value="E07000179=QS701EW">
#         Method of Travel to Work Quick Stats QS701EW
#        </option>
#        <option value="E07000179=QS202EW">
#         Multiple Ethnic Groups Quick Stats QS202EW
#        </option>
#        <option value="E07000179=KS202EW">
#         National Identity Key Stats KS202EW
#        </option>
#        <option value="E07000179=QS607EW">
#         NS-Sec Quick Stats QS607EW
#        </option>
#        <option value="E07000179=KS611EW">
#         NS-SeC Key Stats KS611EW
#        </option>
#        <option value="E07000179=KS613EW">
#         NS-SeC - Females Key Stats KS613EW
#        </option>
#        <option value="E07000179=KS612EW">
#         NS-SeC - Males Key Stats KS612EW
#        </option>
#        <option value="E07000179=QS610EW">
#         NS-Sec of Household Reference Person - HRP Aged under 65 Quick Stats QS610EW
#        </option>
#        <option value="E07000179=QS609EW">
#         NS-Sec of Household Reference Person - People Aged under 65 Quick Stats QS609EW
#        </option>
#        <option value="E07000179=QS608EW">
#         NS-SeC of Household Reference Person - People Aged under 65 Quick Stats QS608EW
#        </option>
#        <option value="E07000179=QS411EW">
#         Number of Bedrooms Quick Stats QS411EW
#        </option>
#        <option value="E07000179=QS407EW">
#         Number of Rooms Quick Stats QS407EW
#        </option>
#        <option value="E07000179=QS412EW">
#         Occupancy Rating (Bedrooms) Quick Stats QS412EW
#        </option>
#        <option value="E07000179=QS408EW">
#         Occupancy Rating (rooms) Quick Stats QS408EW
#        </option>
#        <option value="E07000179=KS608EW">
#         Occupation Key Stats KS608EW
#        </option>
#        <option value="E07000179=QS606EW">
#         Occupation (Minor Groups) Quick Stats QS606EW
#        </option>
#        <option value="E07000179=KS610EW">
#         Occupation - Females Key Stats KS610EW
#        </option>
#        <option value="E07000179=KS609EW">
#         Occupation - Males Key Stats KS609EW
#        </option>
#        <option value="E07000179=KS205EW">
#         Passport Held Key Stats KS205EW
#        </option>
#        <option value="E07000179=QS117EW">
#         People Aged 18 to 64 Living In a One Adult Household Quick Stats QS117EW
#        </option>
#        <option value="E07000179=QS413EW">
#         Persons per Bedroom - Households Quick Stats QS413EW
#        </option>
#        <option value="E07000179=QS414EW">
#         Persons per Bedroom - People Quick Stats QS414EW
#        </option>
#        <option value="E07000179=QS409EW">
#         Persons per Room - Households Quick Stats QS409EW
#        </option>
#        <option value="E07000179=QS410EW">
#         Persons per Room - people Quick Stats QS410EW
#        </option>
#        <option value="E07000179=QS102EW">
#         Population Density Quick Stats QS102EW
#        </option>
#        <option value="E07000179=QS419EW">
#         Position in Communal Establishment Quick Stats QS419EW
#        </option>
#        <option value="E07000179=QS205EW">
#         Proficiency in English Quick Stats QS205EW
#        </option>
#        <option value="E07000179=QS301EW">
#         Provision of Unpaid Care Quick Stats QS301EW
#        </option>
#        <option value="E07000179=KS501EW">
#         Qualifications and Students Key Stats KS501EW
#        </option>
#        <option value="E07000179=QS502EW">
#         Qualifications Gained Quick Stats QS502EW
#        </option>
#        <option value="E07000179=QS208EW">
#         Religion Quick Stats QS208EW
#        </option>
#        <option value="E07000179=KS209EW">
#         Religion Key Stats KS209EW
#        </option>
#        <option value="E07000179=QS210EW">
#         Religion (detailed) Quick Stats QS210EW
#        </option>
#        <option value="E07000179=QS101EW">
#         Residence Type Quick Stats QS101EW
#        </option>
#        <option value="E07000179=KS403EW">
#         Rooms, Bedrooms and Central Heating Key Stats KS403EW
#        </option>
#        <option value="E07000179=QS105EW">
#         Schoolchildren and full-time students at their non term-time Quick Stats QS105EW
#        </option>
#        <option value="E07000179=QS106EW">
#         Second Address Quick Stats QS106EW
#        </option>
#        <option value="E07000179=QS104EW">
#         Sex Quick Stats QS104EW
#        </option>
#        <option value="E07000179=KS402EW">
#         Tenure Key Stats KS402EW
#        </option>
#        <option value="E07000179=QS404EW">
#         Tenure - Household Reference Person aged 65 and Over Quick Stats QS404EW
#        </option>
#        <option value="E07000179=QS405EW">
#         Tenure - Households Quick Stats QS405EW
#        </option>
#        <option value="E07000179=QS403EW">
#         Tenure - People Quick Stats QS403EW
#        </option>
#        <option value="E07000179=KS101EW">
#         Usual Resident Population Key Stats KS101EW
#        </option>
#        <option value="E07000179=KS208WA">
#         Welsh Language Profile Key Stats KS208WA
#        </option>
#        <option value="E07000179=QS206WA">
#         Welsh Language Skills Quick Stats QS206WA
#        </option>
#        <option value="E07000179=KS207WA">
#         Welsh Language Skills Key Stats KS207WA
#        </option>
#        <option value="E07000179=QS207WA">
#         Welsh Language Skills (Detaiiled) Quick Stats QS207WA
#        </option>
#        <option value="E07000179=QS612EW">
#         Year Last Worked Quick Stats QS612EW
#        </option>
#        <option value="E07000179=QS801EW">
#         Year of Arrival in UK Quick Stats QS801EW
#        </option>
#       </select>
#      </form>
#      <noscript>
#       <input type="submit" value="Go"/>
#      </noscript>
#      <!--
# -->
#     </div>
#     <div style="clear:both">
#     </div>
#    </div>
#   </div>
#   <div id="footer">
#    <div id="footer-inner">
#     <div style="float:left; text-align:left; margin:10px 20px 10px 20px;">
#      <a href="/">
#       Home
#      </a>
#      <br/>
#     </div>
#     <div style="float:left; text-align:left; margin:10px 20px 10px 20px;">
#      <a href="/site/about">
#       About
#      </a>
#      <br/>
#      <a href="/site/privacy">
#       Privacy Policy
#      </a>
#      <br/>
#     </div>
#     <div style="float:left; text-align:left; margin:10px 20px 10px 20px;">
#      <a href="/site/output-areas">
#       Output Areas
#      </a>
#      <br/>
#     </div>
#     <div style="clear:both">
#      <p>
#       UKCensusdata.com has the 2011 census data for all English and Welsh local authorities, wards and output areas. View the data as
# tables, or visualise it on a graph. UKCensusdata.com is an independent site and is not affiliated with any government department.
#      </p>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-25123446-22']);
#   _gaq.push(['_setDomainName', 'ukcensusdata.com']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <!--<script src="/js/cookiemonster.js"></script> -->
#   <script type="text/javascript">
#    stLight.options({publisher: "bec009f2-942b-4074-a394-9e5ebc9a4abd", doNotHash: false, doNotCopy: false, hashAddressBar: true});
#   </script>
#   <script>
#    var options={ "publisher": "bec009f2-942b-4074-a394-9e5ebc9a4abd", "position": "right", "ad": { "visible": false, "openDelay": 5, "closeDelay": 0}, "chicklets": { "items": ["facebook", "twitter", "linkedin", "email", "sharethis"]}};
# var st_hover_widget = new sharethis.widgets.hoverbuttons(options);
#   </script>
#  </body>
# </html>

# %%
My_table = soup.find('select')
# print(My_table)
option_text = [x.getText() for x in My_table.find_all('option')]
option_text.pop(0)
option_text

datasets= pd.DataFrame(data=option_text, columns=['Description'])
datasets['Key'] = datasets['Description'].apply(lambda x: x.split()[-1])
datasets.to_csv('dataset_keys.csv')

# option_text[0].split()[-1]

# %%
url = r'http://ukcensusdata.com/a-e00145769/b-qs103ew'
website_url = requests.get(url).text
tables = pd.read_html(website_url)
tables
# Out:
# [                                          0      1
#  0                            All Residents:  313.0
#  1                     Number of households:  121.0
#  2                   Average household size:    2.6
#  3                  Residents in households:  313.0
#  4             Residents in communal living:    0.0
#  5                          Area (hectares):   12.0
#  6  Population density (people per hectare):   26.6,
#                         0    1
#  0    All categories: Age  313
#  1            Age under 1    4
#  2                  Age 1    5
#  3                  Age 2    5
#  4                  Age 3    9
#  5                  Age 4    3
#  6                  Age 5    6
#  7                  Age 6    2
#  8                  Age 7    2
#  9                  Age 8    2
#  10                 Age 9    3
#  11                Age 10    0
#  12                Age 11    4
#  13                Age 12    2
#  14                Age 13    3
#  15                Age 14    7
#  16                Age 15    3
#  17                Age 16    2
#  18                Age 17    4
#  19                Age 18    4
#  20                Age 19    3
#  21                Age 20    1
#  22                Age 21    1
#  23                Age 22    4
#  24                Age 23    1
#  25                Age 24    1
#  26                Age 25    5
#  27                Age 26    0
#  28                Age 27    3
#  29                Age 28    3
#  ..                   ...  ...
#  72                Age 71    2
#  73                Age 72    4
#  74                Age 73    2
#  75                Age 74    5
#  76                Age 75    3
#  77                Age 76    3
#  78                Age 77    2
#  79                Age 78    4
#  80                Age 79    0
#  81                Age 80    5
#  82                Age 81    6
#  83                Age 82    0
#  84                Age 83    2
#  85                Age 84    0
#  86                Age 85    0
#  87                Age 86    1
#  88                Age 87    3
#  89                Age 88    0
#  90                Age 89    0
#  91                Age 90    0
#  92                Age 91    1
#  93                Age 92    0
#  94                Age 93    0
#  95                Age 94    0
#  96                Age 95    0
#  97                Age 96    0
#  98                Age 97    0
#  99                Age 98    0
#  100               Age 99    0
#  101     Age 100 and over    0
#
#  [102 rows x 2 columns]]

# %%
def getDataset(OA, key):
    """
    Scrapes the specified dataset from the ukcensusdata website.
    OA: Output area unique code from census
    key: Key code referring to census dataset
    
    return: dictionary of key, value pairs
    """
    
    # create the url from parameters
    url = f'http://ukcensusdata.com/a-{OA}/b-{key}'
    # request the HTML
    website_url = requests.get(url).text
    # parse the HTML
    soup = BeautifulSoup(website_url,'lxml')

    # extract the HTML referring to infotable
    table = soup.find('table', attrs={'class':"infotable"})
    # list of keys
    keys = table.find_all('td', attrs={'class':"key"})
    # list of values
    values = table.find_all('td', attrs={'class':"value"})

    # list comprehension to combine lists into key, value tuples
    keyvaluelist = [{k.getText().strip('\n\t'): v.getText().strip('\n\t')} for k,v in zip(keys, values)]
    
    return keyvaluelist



def collectDatasetsOnArea(OA, keys):
    """
    For a given area create a dictionary of the datasets given by keys
    OA: Output area unique code from census
    keys: list of dataset identifier keys
    
    return: dictionary of datasets for the area
    """
    
    datasets = {key: getDataset(OA,key) for key in keys}
    
    return datasets


def collectAllDatasets(areas, keys):
    """
    For a given list of areas and keys extract all data into a dictionary
    areas: list of OA codes
    keys: list of dataset identifier keys
    
    return: dictionary with the following heirachy: {Output_Area: {Dataset_key: Dataset}}
    """
    
    area_data_dict = [{OA: collectDatasetsOnArea(OA, keys)} for OA in areas]
    
    return area_data_dict

# %%
areas = ['E00145678','E00145679','E00145680']#,'E00145681','E00145682','E00145683','E00145684']
keys = ['QS416EW','QS415EW']

data = collectAllDatasets(areas, keys)

# %%
import json

y = json.dumps(data, indent=4)
print(y)
# Out:
# {
#     "E00145678": {
#         "QS416EW": [
#             {
#                 "All categories: Car or van availability": "114"
#             },
#             {
#                 "No cars or vans in household": "0"
#             },
#             {
#                 "1 car or van in household": "25"
#             },
#             {
#                 "2 cars or vans in household": "54"
#             },
#             {
#                 "3 cars or vans in household": "25"
#             },
#             {
#                 "4 or more cars or vans in household": "10"
#             },
#             {
#                 "All categories: Car or van availability": "254"
#             }
#         ],
#         "QS415EW": [
#             {
#                 "All categories: Type of central heating in household": "114"
#             },
#             {
#                 "No central heating ": "5"
#             },
#             {
#                 "Gas central heating": "13"
#             },
#             {
#                 "Electric (including storage heaters) central heating": "6"
#             },
#             {
#                 "Oil central heating": "82"
#             },
#             {
#                 "Solid fuel (for example wood, coal) central heating": "2"
#             },
#             {
#                 "Other central heating": "1"
#             },
#             {
#                 "Two or more types of central heating": "5"
#             }
#         ]
#     },
#     "E00145679": {
#         "QS416EW": [
#             {
#                 "All categories: Car or van availability": "120"
#             },
#             {
#                 "No cars or vans in household": "9"
#             },
#             {
#                 "1 car or van in household": "29"
#             },
#             {
#                 "2 cars or vans in household": "61"
#             },
#             {
#                 "3 cars or vans in household": "11"
#             },
#             {
#                 "4 or more cars or vans in household": "10"
#             },
#             {
#                 "All categories: Car or van availability": "233"
#             }
#         ],
#         "QS415EW": [
#             {
#                 "All categories: Type of central heating in household": "120"
#             },
#             {
#                 "No central heating ": "6"
#             },
#             {
#                 "Gas central heating": "77"
#             },
#             {
#                 "Electric (including storage heaters) central heating": "2"
#             },
#             {
#                 "Oil central heating": "20"
#             },
#             {
#                 "Solid fuel (for example wood, coal) central heating": "4"
#             },
#             {
#                 "Other central heating": "0"
#             },
#             {
#                 "Two or more types of central heating": "11"
#             }
#         ]
#     },
#     "E00145680": {
#         "QS416EW": [
#             {
#                 "All categories: Car or van availability": "96"
#             },
#             {
#                 "No cars or vans in household": "6"
#             },
#             {
#                 "1 car or van in household": "31"
#             },
#             {
#                 "2 cars or vans in household": "44"
#             },
#             {
#                 "3 cars or vans in household": "8"
#             },
#             {
#                 "4 or more cars or vans in household": "7"
#             },
#             {
#                 "All categories: Car or van availability": "172"
#             }
#         ],
#         "QS415EW": [
#             {
#                 "All categories: Type of central heating in household": "96"
#             },
#             {
#                 "No central heating ": "2"
#             },
#             {
#                 "Gas central heating": "70"
#             },
#             {
#                 "Electric (including storage heaters) central heating": "2"
#             },
#             {
#                 "Oil central heating": "15"
#             },
#             {
#                 "Solid fuel (for example wood, coal) central heating": "0"
#             },
#             {
#                 "Other central heating": "1"
#             },
#             {
#                 "Two or more types of central heating": "6"
#             }
#         ]
#     }
# }

# %%
from pandas.io.json import json_normalize

pd.DataFrame.from_dict(data)
# Out:
#                                            E00145678  \
# 0  {'QS416EW': [{'All categories: Car or van avai...
# 1                                                NaN
# 2                                                NaN
#
#                                            E00145679  \
# 0                                                NaN
# 1  {'QS416EW': [{'All categories: Car or van avai...
# 2                                                NaN
#
#                                            E00145680
# 0                                                NaN
# 1                                                NaN
# 2  {'QS416EW': [{'All categories: Car or van avai...

# %%
OA = 'E00145769'
key = 'QS415EW'

# create the url from parameters
url = f'http://ukcensusdata.com/a-{OA}/b-{key}'
# request the HTML
website_url = requests.get(url).text
# parse the HTML
soup = BeautifulSoup(website_url,'lxml')

# extract the HTML referring to infotable
table = soup.find('table', attrs={'class':"infotable"})
# list of keys
pd.read_html(requests.get(url).text)
# keys = table.find_all('td', attrs={'class':"key"})
# # list of values
# values = table.find_all('td', attrs={'class':"value"})

# # list comprehension to combine lists into key, value tuples
# keyvaluelist = [(k.getText().strip('\n\t'), v.getText().strip('\n\t')) for k,v in zip(keys, values)]

# keyvaluelist
# Out:
# [                                          0      1
#  0                            All Residents:  313.0
#  1                     Number of households:  121.0
#  2                   Average household size:    2.6
#  3                  Residents in households:  313.0
#  4             Residents in communal living:    0.0
#  5                          Area (hectares):   12.0
#  6  Population density (people per hectare):   26.6,
#                                                     0    1
#  0  All categories: Type of central heating in hou...  121
#  1                                 No central heating    3
#  2                                Gas central heating  107
#  3  Electric (including storage heaters) central h...    2
#  4                                Oil central heating    5
#  5  Solid fuel (for example wood, coal) central he...    0
#  6                              Other central heating    1
#  7               Two or more types of central heating    3]

# %%
mystring = '\n\t\t\tAll categories: Age\t\t\t'

mystring.strip('\n\t')
# Out:
# 'All categories: Age'
